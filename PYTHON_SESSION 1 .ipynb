# %%
a=10
b=20
c=a+b
print(c)     #shift+enter at a time
# Out:
# 30

# %%
hello today im learning python
# Out:
#   Cell In[15], line 1
#     hello today im learning python
#           ^
# SyntaxError: invalid syntax

# %%
"hello today im learning python"
# Out:
# 'hello today im learning python'

# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
a=10
b=20
a
b  # python bydefaults always provides only last 
   #if you want to see both values print the both values like samw as next down cell
# Out:
# 20

# %%
a=10
b=20
print(a)
print(b) # if want to see all the answwer print everything
# Out:
# 10
# 20

# %%
a=10
b=20 
a,b
# Out:
# (10, 20)

# %%
a=10
b=20 
print(a,b)
# Out:
# 10 20

# %%
a=10
b=20 
print(a),print(b) #this is not coming use both on the above cells like print or (a,b)
# Out:
# 10
# 20
# (None, None)

# %%
hello to today i am learning python
it is very intresting 
it is very easy          # esc+m,esc+m are shortcut keys
i will attend every day # to convert the cell to markdown is esc+m and markdown to code esc+y dont type esc+m or esc+y you get error just press in keyboard.

# %% [markdown]
# # python

# %% [markdown]
# ## python

# %% [markdown]
# ### python

# %% [markdown]
# - square brackets indicates it is in cell mode
# - when the square brackets are not there then the cell is in markdown mode
# - code mode is used to write the coding part
# - markdown mode is uesd to the documentation of entire devlopment like a book

# %% [markdown]
# <img src="https://viso.ai/wp-content/uploads/2024/02/ASI-ANI-AGI-types-of-AI.jpg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1920px; height: 169px; margin: 0px; width: 300px;" alt="Exploring 3 Types of Artificial Intelligence" jsname="kn3ccd">

# %% [markdown]
# # on the aove go to google ,and select one image and, click on right button ,and select inspect ,immidiatile i can see image source in eliments, on that right click edit as html ,click then ctrl+a and then ctrl+c and come to python jypiter notebook and paste crtl+v,then esc+m shortcut keys must and then image comes in notebook

# %% [markdown]
# ### vs code not do this image process but juypter we can wright code and explain code and also draw graphs and can also do maths

# %%
crtl+a
crtl+c
crtl+v
esc+m
shift enter
